# %% [markdown]
# # Test All Possible Regressions in sklearn
#
# This project lists and different model performances on cars dataset.
#
# Uses other columns to predict Price column.

# %%
import pandas as pd

df_original = pd.read_csv("datasets/cars.csv")
df = df_original.drop("Car_ID", axis=1)
df.head()
# Out:
#      Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Toyota  Corolla  2018              50000    Petrol       Manual
# 1    Honda    Civic  2019              40000    Petrol    Automatic
# 2     Ford  Mustang  2017              20000    Petrol    Automatic
# 3   Maruti    Swift  2020              30000    Diesel       Manual
# 4  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %% [markdown]
# ## Preprocessing
# Use label encoder to transform strings into index numbers

# %%
from sklearn.preprocessing import LabelEncoder

le_brand = LabelEncoder()
le_brand.fit(df["Brand"])
df["Brand"] = le_brand.transform(df["Brand"])

le_model = LabelEncoder()
le_model.fit(df["Model"])
df["Model"] = le_model.transform(df["Model"])

le_fuel_type = LabelEncoder()
le_fuel_type.fit(df["Fuel_Type"])
df["Fuel_Type"] = le_fuel_type.transform(df["Fuel_Type"])

le_transmission = LabelEncoder()
le_transmission.fit(df["Transmission"])
df["Transmission"] = le_transmission.transform(df["Transmission"])

le_owner_type = LabelEncoder()
le_owner_type.fit(df["Owner_Type"])
df["Owner_Type"] = le_owner_type.transform(df["Owner_Type"])

# %% [markdown]
# Preprocessed DataFrame

# %%
df.head()
# Out:
#    Brand  Model  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0      9     15  2018              50000          1             1           0
# 1      3     14  2019              40000          1             0           1
# 2      2     30  2017              20000          1             0           0
# 3      6     42  2020              30000          0             1           2
# 4      4     41  2016              60000          0             0           1
#
#    Mileage  Engine  Power  Seats    Price
# 0       15    1498    108      5   800000
# 1       17    1597    140      5  1000000
# 2       10    4951    395      4  2500000
# 3       23    1248     74      5   600000
# 4       18    1999    194      5   850000

# %% [markdown]
# Input(s) and Output

# %%
X = df.drop("Price", axis=1)
y = pd.DataFrame(df["Price"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=True)

# %% [markdown]
# Split dataset rows for training and testing

# %%
import warnings
from sklearn.utils import all_estimators

# supress sklearn warnings
warnings.filterwarnings("ignore")

regression_classes =  all_estimators(type_filter="regressor")

test_results = []
skipped_regressors = []

for name, class_ in regression_classes:
    try:
        regr = class_()
        regr.fit(X_train, y_train.values.ravel())
        train_score = regr.score(X_train, y_train) * 100
        test_score = regr.score(X_test, y_test) * 100
        test_results.append((name, train_score, test_score))
    except Exception as e:
        skipped_regressors.append((name, e.args[0].args[0] if e.args is Exception else e.args[0]))

# %% [markdown]
# Failed classifiers (requires more parameters to fit)

# %%
for (name, error) in skipped_regressors:
    print(f"{name:25}: {error[0:85]}...")
# Out:
# CCA                      : `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`....
# GammaRegressor           : No matching signature found...
# IsotonicRegression       : Isotonic regression input X should be a 1d array or 2d array with 1 feature...
# MultiOutputRegressor     : MultiOutputRegressor.__init__() missing 1 required positional argument: 'estimator'...
# MultiTaskElasticNet      : For mono-task outputs, use ElasticNet...
# MultiTaskElasticNetCV    : For mono-task outputs, use ElasticNetCVCV...
# MultiTaskLasso           : For mono-task outputs, use ElasticNet...
# MultiTaskLassoCV         : For mono-task outputs, use LassoCVCV...
# PLSCanonical             : `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`....
# PoissonRegressor         : No matching signature found...
# RegressorChain           : _BaseChain.__init__() missing 1 required positional argument: 'base_estimator'...
# StackingRegressor        : StackingRegressor.__init__() missing 1 required positional argument: 'estimators'...
# TweedieRegressor         : No matching signature found...
# VotingRegressor          : VotingRegressor.__init__() missing 1 required positional argument: 'estimators'...

# %% [markdown]
# ## Results

# %%
pd.set_option("display.max_rows", None)
pd.options.display.float_format = '{:,.2f}'.format
table = pd.DataFrame(test_results, columns=["Name", "Train Score", "Test Score"])
table.set_index("Name").sort_values(by="Test Score", ascending=False)
# Out:
#                                                          Train Score  \
# Name
# ExtraTreesRegressor                                           100.00
# RandomForestRegressor                                          98.71
# GradientBoostingRegressor                                      99.98
# BaggingRegressor                                               98.53
# AdaBoostRegressor                                              98.49
# HistGradientBoostingRegressor                                  95.08
# DecisionTreeRegressor                                         100.00
# PLSRegression                                                  83.39
# ElasticNet                                                     81.59
# OrthogonalMatchingPursuitCV                                    74.82
# LassoCV                                                        74.74
# QuantileRegressor                                              70.74
# KernelRidge                                                    87.03
# TheilSenRegressor                                              82.22
# Ridge                                                          87.56
# LassoLarsIC                                                    87.22
# RANSACRegressor                                                78.32
# HuberRegressor                                                 70.40
# RidgeCV                                                        87.62
# Lasso                                                          87.63
# LassoLars                                                      87.63
# LassoLarsCV                                                    87.63
# LinearRegression                                               87.63
# TransformedTargetRegressor                                     87.63
# ARDRegression                                                  72.66
# LarsCV                                                         85.51
# Lars                                                           84.83
# ExtraTreeRegressor                                            100.00
# OrthogonalMatchingPursuit                                      46.38
# LinearSVR                                                      22.61
# ElasticNetCV                                                   35.46
# KNeighborsRegressor                                            60.10
# SVR                                                            -5.07
# NuSVR                                                          -0.05
# DummyRegressor                                                  0.00
# BayesianRidge                                                   0.00
# PassiveAggressiveRegressor                                    -24.73
# GaussianProcessRegressor                                      100.00
# MLPRegressor                                                 -228.21
# SGDRegressor                  -11,925,605,919,192,588,765,626,368.00
# RadiusNeighborsRegressor                                      100.00
#
#                                                              Test Score
# Name
# ExtraTreesRegressor                                               93.96
# RandomForestRegressor                                             90.71
# GradientBoostingRegressor                                         89.09
# BaggingRegressor                                                  88.21
# AdaBoostRegressor                                                 88.04
# HistGradientBoostingRegressor                                     85.96
# DecisionTreeRegressor                                             83.22
# PLSRegression                                                     81.18
# ElasticNet                                                        79.99
# OrthogonalMatchingPursuitCV                                       76.81
# LassoCV                                                           76.65
# QuantileRegressor                                                 76.46
# KernelRidge                                                       76.39
# TheilSenRegressor                                                 76.34
# Ridge                                                             76.18
# LassoLarsIC                                                       75.89
# RANSACRegressor                                                   75.77
# HuberRegressor                                                    75.49
# RidgeCV                                                           75.06
# Lasso                                                             74.91
# LassoLars                                                         74.91
# LassoLarsCV                                                       74.91
# LinearRegression                                                  74.91
# TransformedTargetRegressor                                        74.91
# ARDRegression                                                     73.38
# LarsCV                                                            68.71
# Lars                                                              66.35
# ExtraTreeRegressor                                                63.09
# OrthogonalMatchingPursuit                                         57.11
# LinearSVR                                                         48.58
# ElasticNetCV                                                      36.16
# KNeighborsRegressor                                               31.22
# SVR                                                               -0.60
# NuSVR                                                             -1.42
# DummyRegressor                                                    -1.95
# BayesianRidge                                                     -1.95
# PassiveAggressiveRegressor                                        -5.83
# GaussianProcessRegressor                                         -66.84
# MLPRegressor                                                    -172.39
# SGDRegressor                     -13,950,061,204,244,690,666,258,432.00
# RadiusNeighborsRegressor      -4,728,196,808,367,432,338,006,605,824.00
